# %% [markdown]
# 1. Note 1

# %%
a,b,c = 2,3,a + b
print(c)
# Out:
# 5

# %%
a,b,c = b + c ,3,4
print(a)
# Out:
# 7

# %% [markdown]
# It works in compiler.....But in interpreter it will show error(a is not defined) for the first code cell because the interpreter starts from the right...so a value is not yet allocated so if we print c it shows the above error.

# %%
# WAP to sum elements in array
# 1
arr = [1,2,3,4]
sum = arr[0] + arr[1] + arr[2] + arr[3]
print(sum)
# Out:
# 10

# %%
# 2
arr = [1,2,3,4]
sum = 0
for i in arr:
    sum = sum + i
print(sum)
# Out:
# 10
